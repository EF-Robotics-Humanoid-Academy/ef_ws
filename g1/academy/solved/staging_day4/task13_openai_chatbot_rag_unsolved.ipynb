# %% [markdown]
# # G1 Academy Bonus - Task 13: Add Knowledge (RAG) to the Chatbot

# %% [markdown]
# ## Introduction
# Extend Task 12's `chat_turn` so it can answer questions using the German knowledge file `g1_academy_knowledge_de.json` (same shape as `modules/scripts/ollama_ai/*.sample.json`) -- this is retrieval-augmented generation (RAG): look up relevant facts first, then let the model answer using them.
#
# - `openai_api_util.load_knowledge_base(path)` -> a list of `{"question", "answer", "category"}`.
# - `openai_api_util.retrieve_relevant(knowledge, query, top_k=3)` -> the best-matching entries for `query`.
#
# This task is mostly done with Codex: you already have everything it needs (Task 12's `chat_turn`, and the two functions above).

# %%
# TODO: knowledge = openai_api_util.load_knowledge_base("g1_academy_knowledge_de.json")
raise NotImplementedError("Complete this task section")

# %% [markdown]
# ## Codex prompt
# ```
# I already have chat_turn(text) from Task 12 (uses openai_api_util.chat_reply(client, text,
# history=history) and speaks the reply with g1.say(reply, language="DE")).
#
# I also have knowledge = openai_api_util.load_knowledge_base("g1_academy_knowledge_de.json"), a list of
# {"question", "answer", "category"}, and openai_api_util.retrieve_relevant(knowledge, query, top_k=3),
# which returns the most relevant entries.
#
# Write a new function chat_turn_with_knowledge(text) that:
# 1. calls retrieve_relevant(knowledge, text, top_k=3) to find the 3 most relevant knowledge entries,
# 2. adds them as extra context (question+answer pairs) before the user's message -- e.g. as one extra
#    {"role": "system", ...} message inserted into history, or appended to the question passed in --
#    so the model can use them to answer,
# 3. otherwise behaves exactly like chat_turn: calls openai_api_util.chat_reply(...), updates history,
#    prints the reply, and speaks it with g1.say(reply, language="DE").
#
# Only use the existing openai_api_util functions -- do not create a new OpenAI client.
# ```

# %%
# TODO: write chat_turn_with_knowledge(text) here (see the Codex prompt above), then test it.
raise NotImplementedError("Complete this task section")
